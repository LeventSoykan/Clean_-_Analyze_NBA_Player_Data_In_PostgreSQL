# %% [markdown]
# ### TODO
#
# * Glossary - https://www.basketball-reference.com/about/glossary.html
#
# * Scoring and min played with age
# * Select a player and analyze performance over time
# * Find the best offensive and defensive teams for 5 year period
# * Find best university to be good guard
# * Find the best scorer, rebounder on career average
# * Height weight averages for positions

# %%
# %load_ext sql

# %%
# %%sql
# postgresql://postgres:postgres@localhost/nbadb

# %%
# %%sql
# SET search_path TO public;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT * FROM INFORMATION_SCHEMA.TABLES
# WHERE table_schema = 'public';
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 2 rows affected.
# [('nbadb', 'public', 'players', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('nbadb', 'public', 'seasons', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# %%sql
# SELECT
#     column_name, data_type
# FROM
#     INFORMATION_SCHEMA.COLUMNS
# WHERE
#     table_schema = 'public'
# AND
#     table_name = 'players'
# ORDER BY
#     column_name;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 8 rows affected.
# [('birth_date', 'text'),
#  ('college', 'text'),
#  ('height', 'text'),
#  ('name', 'text'),
#  ('position', 'text'),
#  ('weight', 'double precision'),
#  ('year_end', 'bigint'),
#  ('year_start', 'bigint')]

# %%
# %%sql
# SELECT
#     birth_date, CAST(birth_date AS date) birth_as_date
# FROM
#     players
# LIMIT
#     10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [('June 24, 1968', datetime.date(1968, 6, 24)),
#  ('April 7, 1946', datetime.date(1946, 4, 7)),
#  ('April 16, 1947', datetime.date(1947, 4, 16)),
#  ('March 9, 1969', datetime.date(1969, 3, 9)),
#  ('November 3, 1974', datetime.date(1974, 11, 3)),
#  ('December 11, 1976', datetime.date(1976, 12, 11)),
#  ('May 6, 1954', datetime.date(1954, 5, 6)),
#  ('July 27, 1932', datetime.date(1932, 7, 27)),
#  ('February 9, 1919', datetime.date(1919, 2, 9)),
#  ('August 1, 1993', datetime.date(1993, 8, 1))]

# %%
# %%sql
# UPDATE
#     players
# SET
#     birth_date = CAST(birth_date AS date);
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 4550 rows affected.
# []

# %%
# %%sql
# SELECT
#     DATE_PART('month', birth_date::date) AS birth_month
# FROM
#     players
# LIMIT
#     10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [(3.0,),
#  (2.0,),
#  (5.0,),
#  (8.0,),
#  (3.0,),
#  (2.0,),
#  (6.0,),
#  (10.0,),
#  (6.0,),
#  (4.0,)]

# %%
# %%sql
# SELECT
#     column_name, data_type
# FROM
#     INFORMATION_SCHEMA.COLUMNS
# WHERE
#     table_schema = 'public'
# AND
#     table_name = 'players'
# ORDER BY
#     column_name;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 8 rows affected.
# [('birth_date', 'text'),
#  ('college', 'text'),
#  ('height', 'text'),
#  ('name', 'text'),
#  ('position', 'text'),
#  ('weight', 'double precision'),
#  ('year_end', 'bigint'),
#  ('year_start', 'bigint')]

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN
#     birth_date
# SET DATA TYPE
#     date
# USING
#     CAST(birth_date AS date);
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     *
# FROM
#     players
# LIMIT
#     10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [('Marco Belinelli', 2008, 2018, 'G-F', '195.58', 95.25432, datetime.date(1986, 3, 25), None),
#  ('Mike Bratz', 1978, 1986, 'G', '187.96', 83.91452, datetime.date(1955, 10, 17), 'Stanford University'),
#  ('Cheikh Samb', 2008, 2009, 'C', '215.90', 111.13004, datetime.date(1984, 10, 22), None),
#  ('Radisav Curcic', 1993, 1993, 'C', '208.28', 124.7378, datetime.date(1965, 9, 26), None),
#  ('Danilo Gallinari', 2009, 2018, 'F', '208.28', 102.0582, datetime.date(1988, 8, 8), None),
#  ('Tony Kappen', 1947, 1947, 'G', '177.80', 74.84268, datetime.date(1919, 4, 13), None),
#  ('Joe Kennedy', 1969, 1971, 'F', '198.12', 95.25432, datetime.date(1947, 1, 12), 'Duke University'),
#  ('Salah Mejri', 2016, 2018, 'C', '215.90', 111.13004, datetime.date(1986, 6, 15), None),
#  ('Nikola Pekovic', 2011, 2016, 'C', '210.82', 139.252744, datetime.date(1986, 1, 3), None),
#  ('Stephen Wilson', 1971, 1972, 'G', '195.58', 83.91452, datetime.date(1948, 10, 16), 'Hanover College')]

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN
#     college
# SET DATA TYPE
#     varchar(255);
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# UPDATE
#     players
# SET
#     height = SPLIT_PART(height, '-', 1)::integer * 30.48 + SPLIT_PART(height, '-', 2)::integer * 2.54,
#     weight = weight::numeric * 0.453592;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 4550 rows affected.
# []

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN
#     weight
# SET DATA TYPE
#     integer;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN
#     height
# SET DATA TYPE
#     integer
# USING
#     height::numeric::integer;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     name,
#     SUBSTRING(name FROM 1 FOR (LENGTH(name) - STRPOS(REVERSE(name), ' '))) as firstname,
#     REVERSE(SPLIT_PART(REVERSE(name), ' ', 1)) lastname
# FROM
#     players
# WHERE
#     name ~ '\w+\s\w+\s'
# LIMIT
#     10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [('Billy Ray Bates', 'Billy Ray', 'Bates'),
#  ('George Bon Salle', 'George Bon', 'Salle'),
#  ('Joe Barry Carroll', 'Joe Barry', 'Carroll'),
#  ('Nando De Colo', 'Nando De', 'Colo'),
#  ('Vinny Del Negro', 'Vinny Del', 'Negro'),
#  ('Jo Jo English', 'Jo Jo', 'English'),
#  ('Hot Rod Hundley', 'Hot Rod', 'Hundley'),
#  ('Wah Wah Jones', 'Wah Wah', 'Jones'),
#  ('Horacio Llamas Grey', 'Horacio Llamas', 'Grey'),
#  ('John Lucas III', 'John Lucas', 'III')]

# %%
# %%sql
# SELECT
#     *,
#     REGEXP_SPLIT_TO_TABLE(position,'-')
# FROM
#     players
# LIMIT
#     10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [('Marco Belinelli', 2008, 2018, 'G-F', 196, 95, datetime.date(1986, 3, 25), None, 'G'),
#  ('Marco Belinelli', 2008, 2018, 'G-F', 196, 95, datetime.date(1986, 3, 25), None, 'F'),
#  ('Mike Bratz', 1978, 1986, 'G', 188, 84, datetime.date(1955, 10, 17), 'Stanford University', 'G'),
#  ('Cheikh Samb', 2008, 2009, 'C', 216, 111, datetime.date(1984, 10, 22), None, 'C'),
#  ('Radisav Curcic', 1993, 1993, 'C', 208, 125, datetime.date(1965, 9, 26), None, 'C'),
#  ('Danilo Gallinari', 2009, 2018, 'F', 208, 102, datetime.date(1988, 8, 8), None, 'F'),
#  ('Tony Kappen', 1947, 1947, 'G', 178, 75, datetime.date(1919, 4, 13), None, 'G'),
#  ('Joe Kennedy', 1969, 1971, 'F', 198, 95, datetime.date(1947, 1, 12), 'Duke University', 'F'),
#  ('Salah Mejri', 2016, 2018, 'C', 216, 111, datetime.date(1986, 6, 15), None, 'C'),
#  ('Nikola Pekovic', 2011, 2016, 'C', 211, 139, datetime.date(1986, 1, 3), None, 'C')]

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN
#     position
# SET DATA TYPE
#     varchar(5);
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN
#     name
# SET DATA TYPE
#     varchar(255);
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     name,
#     birth_date,
#     COUNT(*)
# FROM
#     players
# GROUP BY
#     name, birth_date
# HAVING
#     COUNT(*) > 1;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE
#     players
# ADD COLUMN id serial PRIMARY KEY;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     *
# FROM
#     seasons
# LIMIT
#     10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [(1950.0, 'Curly Armstrong', 'G-F', 31.0, 'FTW', 63.0, None, None, None, 0.368, None, 0.467, None, None, None, None, None, None, None, None, None, -0.1, 3.6, 3.5, None, None, None, None, None, None, 144.0, 516.0, 0.27899999999999997, None, None, None, 144.0, 516.0, 0.27899999999999997, 0.27899999999999997, 170.0, 241.0, 0.705, None, None, None, 176.0, None, None, None, 217.0, 458.0),
#  (1950.0, 'Cliff Barker', 'SG', 29.0, 'INO', 49.0, None, None, None, 0.435, None, 0.387, None, None, None, None, None, None, None, None, None, 1.6, 0.6, 2.2, None, None, None, None, None, None, 102.0, 274.0, 0.37200000000000005, None, None, None, 102.0, 274.0, 0.37200000000000005, 0.37200000000000005, 75.0, 106.0, 0.708, None, None, None, 109.0, None, None, None, 99.0, 279.0),
#  (1950.0, 'Leo Barnhorst', 'SF', 25.0, 'CHS', 67.0, None, None, None, 0.39399999999999996, None, 0.259, None, None, None, None, None, None, None, None, None, 0.9, 2.8, 3.6, None, None, None, None, None, None, 174.0, 499.0, 0.349, None, None, None, 174.0, 499.0, 0.349, 0.349, 90.0, 129.0, 0.698, None, None, None, 140.0, None, None, None, 192.0, 438.0),
#  (1950.0, 'Ed Bartels', 'F', 24.0, 'TOT', 15.0, None, None, None, 0.312, None, 0.395, None, None, None, None, None, None, None, None, None, -0.5, -0.1, -0.6, None, None, None, None, None, None, 22.0, 86.0, 0.256, None, None, None, 22.0, 86.0, 0.256, 0.256, 19.0, 34.0, 0.5589999999999999, None, None, None, 20.0, None, None, None, 29.0, 63.0),
#  (1950.0, 'Ed Bartels', 'F', 24.0, 'DNN', 13.0, None, None, None, 0.308, None, 0.37799999999999995, None, None, None, None, None, None, None, None, None, -0.5, -0.1, -0.6, None, None, None, None, None, None, 21.0, 82.0, 0.256, None, None, None, 21.0, 82.0, 0.256, 0.256, 17.0, 31.0, 0.5479999999999999, None, None, None, 20.0, None, None, None, 27.0, 59.0),
#  (1950.0, 'Ed Bartels', 'F', 24.0, 'NYK', 2.0, None, None, None, 0.376, None, 0.75, None, None, None, None, None, None, None, None, None, 0.0, 0.0, 0.0, None, None, None, None, None, None, 1.0, 4.0, 0.25, None, None, None, 1.0, 4.0, 0.25, 0.25, 2.0, 3.0, 0.667, None, None, None, 0.0, None, None, None, 2.0, 4.0),
#  (1950.0, 'Ralph Beard', 'G', 22.0, 'INO', 60.0, None, None, None, 0.42200000000000004, None, 0.301, None, None, None, None, None, None, None, None, None, 3.6, 1.2, 4.8, None, None, None, None, None, None, 340.0, 936.0, 0.363, None, None, None, 340.0, 936.0, 0.363, 0.363, 215.0, 282.0, 0.762, None, None, None, 233.0, None, None, None, 132.0, 895.0),
#  (1950.0, 'Gene Berce', 'G-F', 23.0, 'TRI', 3.0, None, None, None, 0.275, None, 0.313, None, None, None, None, None, None, None, None, None, -0.1, 0.0, -0.1, None, None, None, None, None, None, 5.0, 16.0, 0.313, None, None, None, 5.0, 16.0, 0.313, 0.313, 0.0, 5.0, 0.0, None, None, None, 2.0, None, None, None, 6.0, 10.0),
#  (1950.0, 'Charlie Black', 'F-C', 28.0, 'TOT', 65.0, None, None, None, 0.34600000000000003, None, 0.395, None, None, None, None, None, None, None, None, None, -2.2, 5.0, 2.8, None, None, None, None, None, None, 226.0, 813.0, 0.278, None, None, None, 226.0, 813.0, 0.278, 0.278, 209.0, 321.0, 0.6509999999999999, None, None, None, 163.0, None, None, None, 273.0, 661.0),
#  (1950.0, 'Charlie Black', 'F-C', 28.0, 'FTW', 36.0, None, None, None, 0.36200000000000004, None, 0.48, None, None, None, None, None, None, None, None, None, -0.7, 2.2, 1.5, None, None, None, None, None, None, 125.0, 435.0, 0.287, None, None, None, 125.0, 435.0, 0.287, 0.287, 132.0, 209.0, 0.632, None, None, None, 75.0, None, None, None, 140.0, 382.0)]

# %%
# %%sql
# ALTER TABLE
#     players
# ALTER COLUMN name SET NOT NULL;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     column_name
# FROM
#     INFORMATION_SCHEMA.columns
# WHERE
#     table_name = 'seasons';
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 52 rows affected.
# [('year',),
#  ('player',),
#  ('pos',),
#  ('age',),
#  ('tm',),
#  ('g',),
#  ('gs',),
#  ('mp',),
#  ('per',),
#  ('ts_pct',),
#  ('3par',),
#  ('ftr',),
#  ('orb_pct',),
#  ('drb_pct',),
#  ('trb_pct',),
#  ('ast_pct',),
#  ('stl_pct',),
#  ('blk_pct',),
#  ('tov_pct',),
#  ('usg_pct',),
#  ('blanl',),
#  ('ows',),
#  ('dws',),
#  ('ws',),
#  ('ws/48',),
#  ('blank2',),
#  ('obpm',),
#  ('dbpm',),
#  ('bpm',),
#  ('vorp',),
#  ('fg',),
#  ('fga',),
#  ('fg_pct',),
#  ('3p',),
#  ('3pa',),
#  ('3p_pct',),
#  ('2p',),
#  ('2pa',),
#  ('2p_pct',),
#  ('efg_pct',),
#  ('ft',),
#  ('fta',),
#  ('ft_pct',),
#  ('orb',),
#  ('drb',),
#  ('trb',),
#  ('ast',),
#  ('stl',),
#  ('blk',),
#  ('tov',),
#  ('pf',),
#  ('pts',)]

# %%
# %%sql
# ALTER TABLE
#     seasons
# ALTER COLUMN
#     pos
# SET DATA TYPE
#     varchar(5)
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# ALTER COLUMN
#     tm
# SET DATA TYPE
#     varchar(5)
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# ALTER COLUMN
#     tm
# SET DATA TYPE
#     varchar(255)
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# ADD COLUMN
#     player_id integer;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     COUNT(*)
# FROM
#     seasons
# WHERE
#     player IS NULL;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 1 rows affected.
# [(67,)]

# %%
# %%sql
# DELETE FROM
#     seasons
# WHERE
#     player IS NULL;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 67 rows affected.
# []

# %%
# %%sql
# SELECT
#     COUNT(*)
# FROM
#     seasons
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 1 rows affected.
# [(24624,)]

# %%
# %%sql
# SELECT
#     COUNT(*), player, year, tm, age
# FROM
#     seasons
# GROUP BY
#     player, year, tm, age
# HAVING
#     COUNT(*)>1;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# ADD COLUMN id serial PRIMARY KEY;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# ADD COLUMN player_id integer;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# UPDATE
#     seasons
# SET
#     player_id = temp_table.pid
# FROM (
#     SELECT
#     s.player, p.name, p.id AS pid, s.id AS sid
#     FROM
#         seasons AS s
#     LEFT JOIN
#         players AS p
#     ON
#         s.player = REGEXP_REPLACE(p.name, '(\w+\s+\w+.?)\s.+', '\1')
# ) AS temp_table
# WHERE
#     seasons.id = temp_table.sid AND seasons.id BETWEEN 25000 AND 30000;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 0 rows affected.
# []

# %%
# %%sql
# SELECT
#     s.player, p.name, p.id AS player_id, s.id
# FROM
#     seasons AS s
# LEFT JOIN
#     players AS p
# ON
#     s.player = REGEXP_REPLACE(p.name, '(\w+\s+\w+.?)\s.+', '\1')
# LIMIT
#     20;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 20 rows affected.
# [('Ariel Maughan', 'Ariel Maughan', 15, 416),
#  ('Ariel Maughan', 'Ariel Maughan', 15, 159),
#  ('Forest Able', 'Forest Able', 25, 1123),
#  ('Don Ackerman', 'Don Ackerman', 29, 777),
#  ('Gary Alcorn', 'Gary Alcorn', 55, 1568),
#  ('Gary Alcorn', 'Gary Alcorn', 55, 1451),
#  ('Bob Anderegg', 'Bob Anderegg', 91, 1452),
#  ('Don Anielak', 'Don Anielak', 120, 908),
#  ('Stacey Arceneaux', 'Stacey Arceneaux', 133, 1672),
#  ('Paul Arizin', 'Paul Arizin', 140, 1673),
#  ('Paul Arizin', 'Paul Arizin', 140, 1569),
#  ('Paul Arizin', 'Paul Arizin', 140, 1453),
#  ('Paul Arizin', 'Paul Arizin', 140, 1341),
#  ('Paul Arizin', 'Paul Arizin', 140, 1230),
#  ('Paul Arizin', 'Paul Arizin', 140, 1124),
#  ('Paul Arizin', 'Paul Arizin', 140, 1017),
#  ('Paul Arizin', 'Paul Arizin', 140, 909),
#  ('Paul Arizin', 'Paul Arizin', 140, 313),
#  ('Paul Arizin', 'Paul Arizin', 140, 487),
#  ('Bob Armstrong', 'Bob Armstrong', 143, 1125)]

# %%
# %%sql
# UPDATE
#     seasons
# SET
#     player = REPLACE(player, '*', '')
# WHERE
#     player LIKE '%*%';
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 1528 rows affected.
# []

# %%
# %%sql
# SELECT
#     name, DATE_PART('year', birth_date)
# FROM
#     players
# WHERE
#     name LIKE '%Walter Tavares%'
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 0 rows affected.
# []

# %%
# %%sql
# DELETE FROM
#     seasons
# WHERE
#     player IN ('Johnny Macknowski', 'Sheldon McClellan', 'Walter Tavares')
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 4 rows affected.
# []

# %%
# %%sql
# ALTER TABLE
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# ADD CONSTRAINT fkey_player FOREIGN KEY (player_id) REFERENCES players(id);
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# DROP COLUMN
#     age;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT
#     COUNT(*)
# FROM
#     seasons
# GROUP BY
#     blanl, blank2
# HAVING
#     blanl IS NOT NULL
#     OR
#     blank2 IS NOT NULL;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# DROP COLUMN
#     blanl;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# ALTER TABLE
#     seasons
# DROP COLUMN
#     blank2;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# Done.
# []

# %%
# %%sql
# SELECT * FROM seasons LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 10 rows affected.
# [(1951.0, 'Ariel Maughan', 'F', 'WSC', 35.0, None, None, None, 0.418, None, 0.49200000000000005, None, None, None, None, None, None, None, None, 0.5, 0.5, 1.1, None, None, None, None, None, 78.0, 250.0, 0.312, None, None, None, 78.0, 250.0, 0.312, 0.312, 98.0, 123.0, 0.797, None, None, 141.0, 48.0, None, None, None, 91.0, 254.0, 416, 15),
#  (1950.0, 'Ariel Maughan', 'F', 'STB', 68.0, None, None, None, 0.359, None, 0.35700000000000004, None, None, None, None, None, None, None, None, -1.1, 0.6, -0.5, None, None, None, None, None, 160.0, 574.0, 0.27899999999999997, None, None, None, 160.0, 574.0, 0.27899999999999997, 0.27899999999999997, 157.0, 205.0, 0.7659999999999999, None, None, None, 101.0, None, None, None, 174.0, 477.0, 159, 15),
#  (1957.0, 'Forest Able', 'G', 'SYR', 1.0, None, 1.0, -41.1, 0.0, None, 0.0, None, None, None, None, None, None, None, None, 0.0, 0.0, 0.0, -2.062, None, None, None, None, 0.0, 2.0, 0.0, None, None, None, 0.0, 2.0, 0.0, 0.0, 0.0, 0.0, None, None, None, 1.0, 1.0, None, None, None, 1.0, 0.0, 1123, 25),
#  (1954.0, 'Don Ackerman', 'PG', 'NYK', 28.0, None, 220.0, 1.0, 0.285, None, 0.444, None, None, None, None, None, None, None, None, -0.7, 0.1, -0.6, -0.12300000000000001, None, None, None, None, 14.0, 63.0, 0.222, None, None, None, 14.0, 63.0, 0.222, 0.222, 15.0, 28.0, 0.536, None, None, 15.0, 23.0, None, None, None, 43.0, 43.0, 777, 29),
#  (1961.0, 'Gary Alcorn', 'C', 'LAL', 20.0, None, 174.0, 2.5, 0.35600000000000004, None, 0.2, None, None, None, None, None, None, None, None, -0.2, 0.2, 0.0, -0.002, None, None, None, None, 12.0, 40.0, 0.3, None, None, None, 12.0, 40.0, 0.3, 0.3, 7.0, 8.0, 0.875, None, None, 50.0, 2.0, None, None, None, 47.0, 31.0, 1568, 55),
#  (1960.0, 'Gary Alcorn', 'C', 'DET', 58.0, None, 670.0, 7.6, 0.33, None, 0.26899999999999996, None, None, None, None, None, None, None, None, -1.9, 0.6, -1.3, -0.09, None, None, None, None, 91.0, 312.0, 0.292, None, None, None, 91.0, 312.0, 0.292, 0.292, 48.0, 84.0, 0.5710000000000001, None, None, 279.0, 22.0, None, None, None, 123.0, 230.0, 1451, 55),
#  (1960.0, 'Bob Anderegg', 'SF', 'NYK', 33.0, None, 373.0, 9.3, 0.41200000000000003, None, 0.294, None, None, None, None, None, None, None, None, -0.1, 0.1, 0.0, 0.002, None, None, None, None, 55.0, 143.0, 0.385, None, None, None, 55.0, 143.0, 0.385, 0.385, 23.0, 42.0, 0.5479999999999999, None, None, 69.0, 29.0, None, None, None, 32.0, 133.0, 1452, 91),
#  (1955.0, 'Don Anielak', 'F', 'NYK', 1.0, None, 10.0, 1.8, 0.26, None, 1.0, None, None, None, None, None, None, None, None, -0.1, 0.0, -0.1, -0.263, None, None, None, None, 0.0, 4.0, 0.0, None, None, None, 0.0, 4.0, 0.0, 0.0, 3.0, 4.0, 0.75, None, None, 2.0, 0.0, None, None, None, 0.0, 3.0, 908, 120),
#  (1962.0, 'Stacey Arceneaux', 'F', 'STL', 7.0, None, 110.0, 10.4, 0.405, None, 0.23199999999999998, None, None, None, None, None, None, None, None, -0.1, 0.0, -0.1, -0.036000000000000004, None, None, None, None, 22.0, 56.0, 0.39299999999999996, None, None, None, 22.0, 56.0, 0.39299999999999996, 0.39299999999999996, 6.0, 13.0, 0.462, None, None, 32.0, 4.0, None, None, None, 10.0, 50.0, 1672, 133),
#  (1962.0, 'Paul Arizin', 'SF', 'PHW', 78.0, None, 2785.0, 14.8, 0.486, None, 0.40299999999999997, None, None, None, None, None, None, None, None, 3.9, 2.5, 6.3, 0.109, None, None, None, None, 611.0, 1490.0, 0.41, None, None, None, 611.0, 1490.0, 0.41, 0.41, 484.0, 601.0, 0.805, None, None, 527.0, 201.0, None, None, None, 307.0, 1706.0, 1673, 140)]

# %%
# %%sql
# SELECT * FROM players WHERE name LIKE '%LeBron%';
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 1 rows affected.
# [('LeBron James', 2004, 2018, 'F-G', 203, 113, datetime.date(1984, 12, 30), None, 1972)]

# %%
# %%sql
# DELETE FROM
#     seasons
# WHERE
#     tm = 'TOT';
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 2123 rows affected.
# []

# %%
# %%sql
# SELECT AVG(gs) FROM seasons WHERE player = 'LeBron James';
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 1 rows affected.
# [(75.71428571428571,)]

# %%
# %%sql
# SELECT
#     COUNT(*), gs IS NULL AS games_started_null, year
# FROM
#     seasons
# GROUP BY
#     year, gs IS NULL
# ORDER BY
#     year;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 70 rows affected.
# [(268, True, 1950.0),
#  (148, True, 1951.0),
#  (120, True, 1952.0),
#  (142, True, 1953.0),
#  (119, True, 1954.0),
#  (98, True, 1955.0),
#  (98, True, 1956.0),
#  (100, True, 1957.0),
#  (105, True, 1958.0),
#  (101, True, 1959.0),
#  (105, True, 1960.0),
#  (99, True, 1961.0),
#  (114, True, 1962.0),
#  (125, True, 1963.0),
#  (124, True, 1964.0),
#  (123, True, 1965.0),
#  (123, True, 1966.0),
#  (128, True, 1967.0),
#  (164, True, 1968.0),
#  (187, True, 1969.0),
#  (186, True, 1970.0),
#  (231, True, 1971.0),
#  (241, True, 1972.0),
#  (242, True, 1973.0),
#  (234, True, 1974.0),
#  (256, True, 1975.0),
#  (256, True, 1976.0),
#  (328, True, 1977.0),
#  (330, True, 1978.0),
#  (313, True, 1979.0),
#  (12, False, 1980.0),
#  (311, True, 1980.0),
#  (322, True, 1981.0),
#  (12, False, 1981.0),
#  (345, False, 1982.0),
#  (355, False, 1983.0),
#  (328, False, 1984.0),
#  (342, False, 1985.0),
#  (354, False, 1986.0),
#  (357, False, 1987.0),
#  (380, False, 1988.0),
#  (396, False, 1989.0),
#  (421, False, 1990.0),
#  (415, False, 1991.0),
#  (425, False, 1992.0),
#  (421, False, 1993.0),
#  (444, False, 1994.0),
#  (430, False, 1995.0),
#  (489, False, 1996.0),
#  (511, False, 1997.0),
#  (494, False, 1998.0),
#  (474, False, 1999.0),
#  (468, False, 2000.0),
#  (490, False, 2001.0),
#  (470, False, 2002.0),
#  (456, False, 2003.0),
#  (517, False, 2004.0),
#  (526, False, 2005.0),
#  (512, False, 2006.0),
#  (487, False, 2007.0),
#  (527, False, 2008.0),
#  (515, False, 2009.0),
#  (512, False, 2010.0),
#  (542, False, 2011.0),
#  (515, False, 2012.0),
#  (523, False, 2013.0),
#  (548, False, 2014.0),
#  (575, False, 2015.0),
#  (527, False, 2016.0),
#  (541, False, 2017.0)]

# %%
# %%sql
# SELECT
#     COUNT(*), "3pa" IS NULL AS three_pt_average_null, year
# FROM
#     seasons
# GROUP BY
#     year, "3pa" IS NULL
# ORDER BY
#     year;
# Out:
#  * postgresql://postgres:***@localhost/nbadb
# 68 rows affected.
# [(268, True, 1950.0),
#  (148, True, 1951.0),
#  (120, True, 1952.0),
#  (142, True, 1953.0),
#  (119, True, 1954.0),
#  (98, True, 1955.0),
#  (98, True, 1956.0),
#  (100, True, 1957.0),
#  (105, True, 1958.0),
#  (101, True, 1959.0),
#  (105, True, 1960.0),
#  (99, True, 1961.0),
#  (114, True, 1962.0),
#  (125, True, 1963.0),
#  (124, True, 1964.0),
#  (123, True, 1965.0),
#  (123, True, 1966.0),
#  (128, True, 1967.0),
#  (164, True, 1968.0),
#  (187, True, 1969.0),
#  (186, True, 1970.0),
#  (231, True, 1971.0),
#  (241, True, 1972.0),
#  (242, True, 1973.0),
#  (234, True, 1974.0),
#  (256, True, 1975.0),
#  (256, True, 1976.0),
#  (328, True, 1977.0),
#  (330, True, 1978.0),
#  (313, True, 1979.0),
#  (323, False, 1980.0),
#  (334, False, 1981.0),
#  (345, False, 1982.0),
#  (355, False, 1983.0),
#  (328, False, 1984.0),
#  (342, False, 1985.0),
#  (354, False, 1986.0),
#  (357, False, 1987.0),
#  (380, False, 1988.0),
#  (396, False, 1989.0),
#  (421, False, 1990.0),
#  (415, False, 1991.0),
#  (425, False, 1992.0),
#  (421, False, 1993.0),
#  (444, False, 1994.0),
#  (430, False, 1995.0),
#  (489, False, 1996.0),
#  (511, False, 1997.0),
#  (494, False, 1998.0),
#  (474, False, 1999.0),
#  (468, False, 2000.0),
#  (490, False, 2001.0),
#  (470, False, 2002.0),
#  (456, False, 2003.0),
#  (517, False, 2004.0),
#  (526, False, 2005.0),
#  (512, False, 2006.0),
#  (487, False, 2007.0),
#  (527, False, 2008.0),
#  (515, False, 2009.0),
#  (512, False, 2010.0),
#  (542, False, 2011.0),
#  (515, False, 2012.0),
#  (523, False, 2013.0),
#  (548, False, 2014.0),
#  (575, False, 2015.0),
#  (527, False, 2016.0),
#  (541, False, 2017.0)]
